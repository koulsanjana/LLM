# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
df = pd.read_excel(open('HIST.xlsx','rb'))
df[:20]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Question  \
# ...

# %%
j=0
k=0
l=0
m=0
for i in range(0, len(df)):
    ada=(df.loc[i, ['ADA']][0])
    curie=(df.loc[i, ['CURIE']][0])
    davinci=(df.loc[i, ['DAVINCI']][0])
    gpt3= (df.loc[i, ['GPT 3.5']][0])
    corr=(df.loc[i, ['Correct']]).astype("string")[0]
    if(corr==ada):
        j=j+1
    if(corr==curie):
        k=k+1
    if(corr==davinci):
        l=l+1
    if(corr==gpt3):
        m=m+1
print("ADA:")
print(j)
print(str((j/165)*100)+ "%")
print("---------------")
print("CURIE:")
print(k)
print(str((k/165)*100)+ "%")
print("---------------")
print("DAVINCI:")
print(l)
print(str((l/165)*100)+ "%")
print("---------------")
print("GPT 3.5:")
print(m)
print(str((m/165)*100)+ "%")
# Out:
# ADA:
# 4
# 2.4242424242424243%
# ---------------
# CURIE:
# 29
# 17.575757575757574%
# ---------------
# DAVINCI:
# 103
# 62.42424242424243%
# ---------------
# GPT 3.5:
# 124
# 75.15151515151514%

# %%
#all 165 length
histCorr1= df.Correct.values
histAda1= df.ADA.values
histCurie1= df.CURIE.values
histDavinci1= df.DAVINCI.values
histGPT1= df['GPT 3.5'].values

#All to string
histAda = [str(x) for x in histAda1]
histCorr = [str(x) for x in histCorr1]
histCurie = [str(x) for x in histCurie1]
histDavinci = [str(x) for x in histDavinci1]
histGPT= [str(x) for x in histGPT1]

#Confusion matrix for history
adahistresult= pd.crosstab(histAda, histCorr)
curiehistresult= pd.crosstab(histCurie, histCorr)
davincihistresult= pd.crosstab(histDavinci, histCorr)
gpthistresult= pd.crosstab(histGPT, histCorr)

import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
fig= plt.figure(figsize=(17,5))
ax1= plt.subplot(221)
ax1.set_title('Ada History')
sn.heatmap(adahistresult, annot=True, cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

ax1= plt.subplot(222)
ax1.set_title('Curie History')
sn.heatmap(curiehistresult, annot=True, cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

fig= plt.figure(figsize=(17,5))
ax1= plt.subplot(223)
ax1.set_title('Davinci History')
sn.heatmap(davincihistresult, annot=True, cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

ax1= plt.subplot(224)
ax1.set_title('GPT 3.5 History')
sn.heatmap(gpthistresult, annot=True, cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')
# Out:
# [Text(0.5, 24.000000000000043, 'Actual'),
#  Text(649.4181818181817, 0.5, 'Predicted')]

# %%
from sklearn.metrics import classification_report
display(pd.DataFrame(classification_report(histCorr, histAda, zero_division=1,output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(histCorr, histCurie,zero_division=1, output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(histCorr, histDavinci, zero_division=1, output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(histCorr, histGPT,zero_division=1, output_dict=True)).T[-3:])
# Out:
#               precision    recall  f1-score     support
# accuracy       0.024242  0.024242  0.024242    0.024242
# macro avg      0.044444  0.184760  0.025332  165.000000
# weighted avg   0.060303  0.024242  0.034028  165.000000
#               precision    recall  f1-score     support
# accuracy       0.175758  0.175758  0.175758    0.175758
# macro avg      0.216667  0.296962  0.154839  165.000000
# weighted avg   0.283251  0.175758  0.206480  165.000000
#               precision    recall  f1-score     support
# accuracy       0.624242  0.624242  0.624242    0.624242
# macro avg      0.529990  0.697576  0.522572  165.000000
# weighted avg   0.661573  0.624242  0.636019  165.000000
#               precision    recall  f1-score     support
# accuracy       0.751515  0.751515  0.751515    0.751515
# macro avg      0.725466  0.714066  0.715558  165.000000
# weighted avg   0.755698  0.751515  0.750088  165.000000

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
df = pd.read_excel(open('MATHS.xlsx','rb'))
df[:10]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                       Question  \
# 0                                                                                                                                                         Answer only with the correct letter: the banker ' s gain of a certain sum due 3 years hence at 10 % per annum is rs . 36 . what is the present worth ? a ) rs . 400 , b ) rs . 300 , c ) rs . 500 , d ) rs . 350 , e ) none of these
# ...

# %%
j=0
k=0
l=0
m=0
for i in range(0, len(df)):
    ada=(df.loc[i, ['ADA']][0])
    curie=(df.loc[i, ['CURIE']][0])
    davinci=(df.loc[i, ['DAVINCI']][0])
    gpt3= (df.loc[i, ['GPT 3.5']][0])
    corr=(df.loc[i, ['Correct']]).astype("string")[0]
    if(corr==ada):
        j=j+1
    if(corr==curie):
        k=k+1
    if(corr==davinci):
        l=l+1
    if(corr==gpt3):
        m=m+1
print("ADA:")
print(j)
print((j/1000)*100)
print("---------------")
print("CURIE:")
print(k)
print((k/1000)*100)
print("---------------")
print("DAVINCI:")
print(l)
print((l/1000)*100)
print("---------------")
print("GPT 3.5:")
print(m)
print((m/1000)*100)
# Out:
# ADA:
# 53
# 5.3
# ---------------
# CURIE:
# 98
# 9.8
# ---------------
# DAVINCI:
# 249
# 24.9
# ---------------
# GPT 3.5:
# 253
# 25.3

# %%
mathCorr1= df.Correct.values
mathAda1= df.ADA.values
mathCurie1= df.CURIE.values
mathDavinci1= df.DAVINCI.values
mathGPT1= df['GPT 3.5'].values

#All to string
mathAda = [str(x) for x in mathAda1]
mathCorr = [str(x) for x in mathCorr1]
mathCurie = [str(x) for x in mathCurie1]
mathDavinci = [str(x) for x in mathDavinci1]
mathGPT= [str(x) for x in mathGPT1]

#Confusion matrix for maths
adamathresult= pd.crosstab(mathAda, mathCorr)
curiemathresult= pd.crosstab(mathCurie, mathCorr)
davincimathresult= pd.crosstab(mathDavinci, mathCorr)
gptmathresult= pd.crosstab(mathGPT, mathCorr)

import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
fig= plt.figure(figsize=(17,5))
ax1= plt.subplot(221)
ax1.set_title('Ada maths')
sn.heatmap(adamathresult, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

ax1= plt.subplot(222)
ax1.set_title('Curie maths')
sn.heatmap(curiemathresult, annot=True, fmt="d",cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

fig= plt.figure(figsize=(17,5))
ax1= plt.subplot(223)
ax1.set_title('Davinci maths')
sn.heatmap(davincimathresult, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

ax1= plt.subplot(224)
ax1.set_title('GPT 3.5 maths')
sn.heatmap(gptmathresult, annot=True, cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')
# Out:
# [Text(0.5, 24.000000000000043, 'Actual'),
#  Text(649.4181818181817, 0.5, 'Predicted')]

# %%
from sklearn.metrics import classification_report
display(pd.DataFrame(classification_report(mathCorr, mathAda, zero_division=1,output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(mathCorr, mathCurie,zero_division=1, output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(mathCorr, mathDavinci, zero_division=1, output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(mathCorr, mathGPT,zero_division=1, output_dict=True)).T[-3:])
# Out:
#               precision    recall  f1-score   support
# accuracy       0.053000  0.053000  0.053000     0.053
# macro avg      0.414944  0.209135  0.050283  1000.000
# weighted avg   0.468360  0.053000  0.062905  1000.000
#               precision    recall  f1-score   support
# accuracy       0.098000  0.098000  0.098000     0.098
# macro avg      0.157277  0.249514  0.096279  1000.000
# weighted avg   0.189317  0.098000  0.113804  1000.000
#               precision    recall  f1-score   support
# accuracy       0.249000  0.249000  0.249000     0.249
# macro avg      0.207626  0.369147  0.202916  1000.000
# weighted avg   0.253964  0.249000  0.248819  1000.000
#               precision    recall  f1-score   support
# accuracy       0.253000  0.253000  0.253000     0.253
# macro avg      0.206795  0.369155  0.193395  1000.000
# weighted avg   0.253755  0.253000  0.239799  1000.000

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
df = pd.read_excel(open('MED.xlsx','rb'))
df[:20]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Question  \
# ...

# %%
j=0
k=0
l=0
m=0
for i in range(0, len(df)):
    ada=str(df.loc[i, ['ADA']][0])
    curie=str(df.loc[i, ['CURIE']][0])
    davinci=str(df.loc[i, ['DAVINCI']][0])
    gpt3= str(df.loc[i, ['GPT 3.5']][0])
    corr=(df.loc[i, ['Correct']]).astype("string")[0]
    if(corr==ada):
        j=j+1
    if(corr==curie):
        k=k+1
    if(corr==davinci):
        l=l+1
    if(corr==gpt3):
        m=m+1
print("ADA:")
print(j)
print((j/1000)*100)
print("---------------")
print("CURIE:")
print(k)
print((k/1000)*100)
print("---------------")
print("DAVINCI:")
print(l)
print((l/1000)*100)
print("---------------")
print("GPT 3.5:")
print(m)
print((m/1000)*100)
# Out:
# ADA:
# 198
# 19.8
# ---------------
# CURIE:
# 85
# 8.5
# ---------------
# DAVINCI:
# 411
# 41.099999999999994
# ---------------
# GPT 3.5:
# 543
# 54.300000000000004

# %%
medCorr1= df.Correct.values
medAda1= df.ADA.values
medCurie1= df.CURIE.values
medDavinci1= df.DAVINCI.values
medGPT1= df['GPT 3.5'].values

#All to string
medAda = [str(x) for x in medAda1]
medCorr = [str(x) for x in medCorr1]
medCurie = [str(x) for x in medCurie1]
medDavinci = [str(x) for x in medDavinci1]
medGPT= [str(x) for x in medGPT1]

#Confusion matrix for med
adamedresult= pd.crosstab(medAda, medCorr)
curiemedresult= pd.crosstab(medCurie, medCorr)
davincimedresult= pd.crosstab(medDavinci, medCorr)
gptmedresult= pd.crosstab(medGPT, medCorr)

import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
fig= plt.figure(figsize=(17,5))
ax1= plt.subplot(221)
ax1.set_title('Ada med')
sn.heatmap(adamedresult, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

ax1= plt.subplot(222)
ax1.set_title('Curie med')
sn.heatmap(curiemedresult, annot=True, fmt="d",cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

fig= plt.figure(figsize=(17,5))
ax1= plt.subplot(223)
ax1.set_title('Davinci med')
sn.heatmap(davincimedresult, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

ax1= plt.subplot(224)
ax1.set_title('GPT 3.5 med')
sn.heatmap(gptmedresult, annot=True,fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')
# Out:
# [Text(0.5, 24.000000000000043, 'Actual'),
#  Text(649.4181818181817, 0.5, 'Predicted')]

# %%
from sklearn.metrics import classification_report
display(pd.DataFrame(classification_report(medCorr, medAda, zero_division=1,output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(medCorr, medCurie,zero_division=1, output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(medCorr, medDavinci, zero_division=1, output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(medCorr, medGPT,zero_division=1, output_dict=True)).T[-3:])
# Out:
#               precision    recall  f1-score   support
# accuracy       0.198000  0.198000  0.198000     0.198
# macro avg      0.196386  0.339704  0.105301  1000.000
# weighted avg   0.247319  0.198000  0.146203  1000.000
#               precision    recall  f1-score   support
# accuracy       0.085000  0.085000  0.085000     0.085
# macro avg      0.160537  0.260728  0.070392  1000.000
# weighted avg   0.204765  0.085000  0.096885  1000.000
#               precision    recall  f1-score   support
# accuracy       0.411000  0.411000  0.411000     0.411
# macro avg      0.354066  0.529677  0.338076  1000.000
# weighted avg   0.445454  0.411000  0.423518  1000.000
#               precision    recall  f1-score   support
# accuracy       0.543000  0.543000  0.543000     0.543
# macro avg      0.447318  0.634989  0.436021  1000.000
# weighted avg   0.569984  0.543000  0.549544  1000.000

# %%
df = pd.read_excel(open('ALLSUB_text.xlsx','rb'))
df= df.drop(df.columns[[0]], axis=1)
df
log, fac = [x for _, x in df.groupby(df['TYPE'] =='F')]
df.groupby(['TYPE']).count()

#Checking different types
venDict={}
ven= (df["TYPE"].values)
for i in ven:
    if (i in venDict):
        venDict[i]+=1
    else:
        venDict[i] =1
#plotting venue types
import matplotlib.pyplot as plt
names = list(venDict.keys())
values = list(venDict.values())
plt.bar(range(len(venDict)), values, tick_label=names, color='chocolate')
# Out:
# <BarContainer object of 2 artists>

# %%
#Finding accuracy
sns.countplot(df['GPT 3.5']).unique()
# Out:
# C:\Users\SANJANA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [247], in <cell line: 2>()
#       1 #Finding accuracy
# ----> 2 sns.countplot(df['GPT 3.5']).unique()
#
# AttributeError: 'AxesSubplot' object has no attribute 'unique'

# %%
df = pd.read_excel(open('HIST.xlsx','rb'))
histType1= df.TYPE.values
df = pd.read_excel(open('MATHS.xlsx','rb'))
mathType1= df.TYPE.values
df = pd.read_excel(open('MED.xlsx','rb'))
medType1= df.TYPE.values
histType = [str(x) for x in histType1]
mathType = [str(x) for x in mathType1]
medType = [str(x) for x in medType1]

# %%
outAda= histAda+mathAda+medAda
outCurie=histCurie+mathCurie+medCurie
outDavinci=histDavinci+mathDavinci+medDavinci
outGPT=histGPT+mathGPT+medGPT
corr=histCorr+mathCorr+medCorr
typeq=histType+mathType+medType

# %%
for i, n in enumerate(outAda):
    if (n == 'a' or n=='A'):
        outAda[i] = '1'
    if (n == 'b' or n=='B'):
        outAda[i] = '2'
    if (n == 'c' or n=='C'):
        outAda[i] = '3'
    if (n == 'd' or n=='D'):
        outAda[i] = '4'
    if (n == 'e' or n=='E'):
        outAda[i] = '5'
for i, n in enumerate(outCurie):
    if (n == 'a' or n=='A'):
        outCurie[i] = '1'
    if (n == 'b' or n=='B'):
        outCurie[i] = '2'
    if (n == 'c' or n=='C'):
        outCurie[i] = '3'
    if (n == 'd' or n=='D'):
        outCurie[i] = '4'
    if (n == 'e' or n=='E'):
        outCurie[i] = '5'

for i, n in enumerate(outDavinci):
    if (n == 'a' or n=='A'):
        outDavinci[i] = '1'
    if (n == 'b' or n=='B'):
        outDavinci[i] = '2'
    if (n == 'c' or n=='C'):
        outDavinci[i] = '3'
    if (n == 'd' or n=='D'):
        outDavinci[i] = '4'
    if (n == 'e' or n=='E'):
        outDavinci[i] = '5'
        
for i, n in enumerate(outGPT):
    if (n == 'a' or n=='A'):
        outGPT[i] = '1'
    if (n == 'b' or n=='B'):
        outGPT[i] = '2'
    if (n == 'c' or n=='C'):
        outGPT[i] = '3'
    if (n == 'd' or n=='D'):
        outGPT[i] = '4'
    if (n == 'e' or n=='E'):
        outGPT[i] = '5'
        
for i, n in enumerate(corr):
    if (n == 'a' or n=='A'):
        corr[i] = '1'
    if (n == 'b' or n=='B'):
        corr[i] = '2'
    if (n == 'c' or n=='C'):
        corr[i] = '3'
    if (n == 'd' or n=='D'):
        corr[i] = '4'
    if (n == 'e' or n=='E'):
        corr[i] = '5'

# %%
list_of_tuples = list(zip(typeq,corr,outAda,outCurie,outDavinci, outGPT))
table1 = pd.DataFrame(list_of_tuples, columns=["Type", "Correct", "Ada", "Curie", "Davinci", "GPT"])
table1
# Out:
#      Type Correct Ada Curie Davinci GPT
# 0       F       4   1     4       4   4
# 1       F       3   0     1       3   3
# 2       F       3   1     4       1   3
# 3       F       1   0     5       1   2
# 4       F       4   1     0       4   4
# ...   ...     ...  ..   ...     ...  ..
# 2160    F       2   2     1       1   2
# 2161    F       4   0     0       3   4
# 2162    L       2   1     0       4   4
# 2163    F       4   0     3       1   2
# 2164    F       2   1     0       0   1
#
# [2165 rows x 6 columns]

# %%
ltable = table1[table1['Type'] == 'L']
ftable = table1[table1['Type'] == 'F']
ftable #655 enteries
ltable #1510
# Out:
#      Type Correct Ada Curie Davinci GPT
# 165     L       1   0     3       4   1
# 166     L       4   0     0       4   5
# 167     L       2   0     0       2   4
# 168     L       2   0     3       4   2
# 169     L       1   1     0       5   5
# ...   ...     ...  ..   ...     ...  ..
# 2154    L       2   1     0       0   2
# 2155    L       3   0     3       3   3
# 2158    L       4   1     1       1   4
# 2159    L       4   1     0       1   2
# 2162    L       2   1     0       4   4
#
# [1510 rows x 6 columns]

# %%
lCorr1= ltable.Correct.values
lAda1= ltable.Ada.values
lCurie1= ltable.Curie.values
lDavinci1= ltable.Davinci.values
lGPT1= ltable.GPT.values

#All to string
lCorr = [str(x) for x in lCorr1]
lAda = [str(x) for x in lAda1]
lCurie = [str(x) for x in lCurie1]
lDavinci = [str(x) for x in lDavinci1]
lGPT= [str(x) for x in lGPT1]

#Confusion matrix for med
adalresult= pd.crosstab(lAda, lCorr)
curielresult= pd.crosstab(lCurie, lCorr)
davincilresult= pd.crosstab(lDavinci, lCorr)
gptlresult= pd.crosstab(lGPT, lCorr)

import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
fig= plt.figure(figsize=(17,5))
ax1= plt.subplot(221)
ax1.set_title('Ada Logical')
sn.heatmap(adalresult, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

ax1= plt.subplot(222)
ax1.set_title('Curie Logical')
sn.heatmap(curielresult, annot=True, fmt="d",cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')


fig= plt.figure(figsize=(17,5))
ax1= plt.subplot(223)
ax1.set_title('Davinci Logical')
sn.heatmap(davincilresult, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

ax1= plt.subplot(224)
ax1.set_title('GPT 3.5 Logical')
sn.heatmap(gptlresult, annot=True,fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')
# Out:
# [Text(0.5, 24.000000000000043, 'Actual'),
#  Text(649.4181818181817, 0.5, 'Predicted')]

# %%
from sklearn.metrics import classification_report
display(pd.DataFrame(classification_report(lCorr, lAda, zero_division=1,output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(lCorr, lCurie,zero_division=1, output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(lCorr, lDavinci, zero_division=1, output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(lCorr, lGPT,zero_division=1, output_dict=True)).T[-3:])
# Out:
#               precision    recall  f1-score      support
# accuracy       0.102649  0.102649  0.102649     0.102649
# macro avg      0.399968  0.240844  0.071771  1510.000000
# weighted avg   0.417518  0.102649  0.098899  1510.000000
#               precision    recall  f1-score      support
# accuracy       0.091391  0.091391  0.091391     0.091391
# macro avg      0.157236  0.245968  0.097103  1510.000000
# weighted avg   0.190306  0.091391  0.112936  1510.000000
#               precision    recall  f1-score      support
# accuracy       0.305298  0.305298  0.305298     0.305298
# macro avg      0.250345  0.406707  0.243576  1510.000000
# weighted avg   0.318302  0.305298  0.309655  1510.000000
#               precision    recall  f1-score      support
# accuracy       0.350993  0.350993  0.350993     0.350993
# macro avg      0.285220  0.435514  0.266346  1510.000000
# weighted avg   0.367689  0.350993  0.346060  1510.000000

# %%
fCorr1= ftable.Correct.values
fAda1= ftable.Ada.values
fCurie1= ftable.Curie.values
fDavinci1= ftable.Davinci.values
fGPT1= ftable.GPT.values

#All to string
fCorr = [str(x) for x in fCorr1]
fAda = [str(x) for x in fAda1]
fCurie = [str(x) for x in fCurie1]
fDavinci = [str(x) for x in fDavinci1]
fGPT= [str(x) for x in fGPT1]

#Confusion matrix for med
adafresults= pd.crosstab(fAda, fCorr)
curiefresults= pd.crosstab(fCurie, fCorr)
davincifresults= pd.crosstab(fDavinci, fCorr)
gptfresults= pd.crosstab(fGPT, fCorr)

import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
fig= plt.figure(figsize=(17,5))
ax1= plt.subplot(221)
ax1.set_title('Ada Factual')
sn.heatmap(adafresults, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

ax1= plt.subplot(222)
ax1.set_title('Curie Factual')
sn.heatmap(curiefresults, annot=True, fmt="d",cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')


fig= plt.figure(figsize=(17,5))
ax1= plt.subplot(223)
ax1.set_title('Davinci Factual')
sn.heatmap(davincifresults, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

ax1= plt.subplot(224)
ax1.set_title('GPT 3.5 Factual')
sn.heatmap(gptfresults, annot=True,fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')
# Out:
# [Text(0.5, 24.000000000000043, 'Actual'),
#  Text(649.4181818181817, 0.5, 'Predicted')]

# %%
from sklearn.metrics import classification_report
display(pd.DataFrame(classification_report(fCorr, fAda, zero_division=1,output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(fCorr, fCurie,zero_division=1, output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(fCorr, fDavinci, zero_division=1, output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(fCorr, fGPT,zero_division=1, output_dict=True)).T[-3:])
# Out:
#               precision    recall  f1-score     support
# accuracy       0.152672  0.152672  0.152672    0.152672
# macro avg      0.090442  0.259231  0.073912  655.000000
# weighted avg   0.143276  0.152672  0.120537  655.000000
#               precision    recall  f1-score     support
# accuracy       0.112977  0.112977  0.112977    0.112977
# macro avg      0.196948  0.246874  0.103211  655.000000
# weighted avg   0.269638  0.112977  0.143387  655.000000
#               precision    recall  f1-score     support
# accuracy       0.461069  0.461069  0.461069    0.461069
# macro avg      0.402494  0.588995  0.403662  655.000000
# weighted avg   0.500050  0.461069  0.475372  655.000000
#               precision    recall  f1-score    support
# accuracy       0.595420  0.595420  0.595420    0.59542
# macro avg      0.496312  0.636947  0.477667  655.00000
# weighted avg   0.621704  0.595420  0.602293  655.00000

# %%
from sklearn.metrics import classification_report
display(pd.DataFrame(classification_report(fCorr, fAda, zero_division=1,output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(fCorr, fCurie,zero_division=1, output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(fCorr, fDavinci, zero_division=1, output_dict=True)).T[-3:])
display(pd.DataFrame(classification_report(fCorr, fGPT,zero_division=1, output_dict=True)).T[-3:])
# Out:
#               precision    recall  f1-score     support
# accuracy       0.152672  0.152672  0.152672    0.152672
# macro avg      0.090442  0.259231  0.073912  655.000000
# weighted avg   0.143276  0.152672  0.120537  655.000000
#               precision    recall  f1-score     support
# accuracy       0.112977  0.112977  0.112977    0.112977
# macro avg      0.196948  0.246874  0.103211  655.000000
# weighted avg   0.269638  0.112977  0.143387  655.000000
#               precision    recall  f1-score     support
# accuracy       0.461069  0.461069  0.461069    0.461069
# macro avg      0.402494  0.588995  0.403662  655.000000
# weighted avg   0.500050  0.461069  0.475372  655.000000
#               precision    recall  f1-score    support
# accuracy       0.595420  0.595420  0.595420    0.59542
# macro avg      0.496312  0.636947  0.477667  655.00000
# weighted avg   0.621704  0.595420  0.602293  655.00000

# %%
#LOGICAL:
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
fig= plt.figure(figsize=(17,5))

ax1= plt.subplot(221)
ax1.set_title('Ada Logical')
sn.heatmap(adalresult, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

ax1= plt.subplot(222)
ax1.set_title('Ada Factual')
sn.heatmap(adafresults, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')


fig= plt.figure(figsize=(17,5))
ax1= plt.subplot(223)
ax1.set_title('Curie Logical')
sn.heatmap(curielresult, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

ax1= plt.subplot(224)
ax1.set_title('Curie Factual')
sn.heatmap(curiefresults, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')
# Out:
# [Text(0.5, 24.000000000000043, 'Actual'),
#  Text(649.4181818181817, 0.5, 'Predicted')]

# %%
fig= plt.figure(figsize=(17,5))
ax1= plt.subplot(221)
ax1.set_title('Davinci Logical')
sn.heatmap(davincilresult, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

ax1= plt.subplot(222)
ax1.set_title('Davinci Factual')
sn.heatmap(davincifresults, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

fig= plt.figure(figsize=(17,5))
ax1= plt.subplot(223)
ax1.set_title('GPT 3.5 Logical')
sn.heatmap(gptlresult, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')

ax1= plt.subplot(224)
ax1.set_title('GPT 3.5 Factual')
sn.heatmap(gptfresults, annot=True, fmt="d", cmap='Blues')
ax1.set(xlabel='Actual', ylabel='Predicted')
# Out:
# [Text(0.5, 24.000000000000043, 'Actual'),
#  Text(649.4181818181817, 0.5, 'Predicted')]

# %% [markdown]
# # CHI SQUARE TEST

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
hist = pd.read_excel(open('HIST.xlsx','rb'))
hist.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Question  \
# ...

# %%
histQuestion=[]
histType=[]
histResulta=[] #1 for correct and 0 for wrong
histResultc=[]
histResultd=[]
histResultg=[]

for i, row in hist.iterrows():
#     histQuestion.append(row["Question"])
    histType.append(row["TYPE"])
    ada=str(row["ADA"])
    curie=str(row['CURIE'])
    davinci=str(row['DAVINCI'])
    gpt3= str(row['GPT 3.5'])
    corr=str((row['Correct']))
    if(corr==ada):
        histResulta.append('1')
    else:
        histResulta.append('0')
    if(corr==curie):
        histResultc.append('1')
    else:
        histResultc.append('0')
    if(corr==davinci):
        histResultd.append('1')
    else:
        histResultd.append('0')
    if(corr==gpt3):
        histResultg.append('1')
    else:
        histResultg.append('0')

# %%
list_of_tuples = list(zip(histType,histResulta,histResultc, histResultd, histResultg))
hist1 = pd.DataFrame(list_of_tuples, columns=["TYPE", "ADA", "CURIE", "DAVINCI", "GPT 3.5"])
hist1
# Out:
#     TYPE ADA CURIE DAVINCI GPT 3.5
# 0      F   0     1       1       1
# 1      F   0     0       1       1
# 2      F   0     0       0       1
# 3      F   0     0       1       0
# 4      F   0     0       1       1
# ..   ...  ..   ...     ...     ...
# 160    F   0     1       1       1
# 161    F   0     0       1       1
# 162    F   0     0       1       0
# 163    F   0     0       1       1
# 164    F   0     1       1       0
#
# [165 rows x 5 columns]

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
math = pd.read_excel(open('MATHS.xlsx','rb'))
math
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                          Question  \
# 0                                                                                                                                                                            Answer only with the correct letter: the banker ' s gain of a certain sum due 3 years hence at 10 % per annum is rs . 36 . what is the present worth ? a ) rs . 400 , b ) rs . 300 , c ) rs . 500 , d ) rs . 350 , e ) none of these
# ...

# %%
mathQuestion=[]
mathType=[]
mathResulta=[] #1 for correct and 0 for wrong
mathResultc=[]
mathResultd=[]
mathResultg=[]

for i, row in math.iterrows():
#     mathQuestion.append(row["Question"])
    mathType.append(row["TYPE"])
    ada=str(row["ADA"])
    curie=str(row['CURIE'])
    davinci=str(row['DAVINCI'])
    gpt3= str(row['GPT 3.5'])
    corr=str((row['Correct']))
    if(corr==ada):
        mathResulta.append('1')
    else:
        mathResulta.append('0')
    if(corr==curie):
        mathResultc.append('1')
    else:
        mathResultc.append('0')
    if(corr==davinci):
        mathResultd.append('1')
    else:
        mathResultd.append('0')
    if(corr==gpt3):
        mathResultg.append('1')
    else:
        mathResultg.append('0')

# %%
list_of_tuples = list(zip(mathType,mathResulta,mathResultc, mathResultd, mathResultg))
math1 = pd.DataFrame(list_of_tuples, columns=["TYPE", "ADA", "CURIE", "DAVINCI", "GPT 3.5"])
math1
# Out:
#     TYPE ADA CURIE DAVINCI GPT 3.5
# 0      L   0     0       0       1
# 1      L   0     0       1       0
# 2      L   0     0       1       0
# 3      L   0     0       0       1
# 4      L   1     0       0       0
# ..   ...  ..   ...     ...     ...
# 995    L   0     0       0       1
# 996    L   0     0       0       1
# 997    L   0     0       1       0
# 998    L   0     0       0       0
# 999    L   0     0       0       0
#
# [1000 rows x 5 columns]

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
med = pd.read_excel(open('MED.xlsx','rb'))
med
# Out:
#                                                                                                                                                                                                                                                                                                                                                               Question  \
# 0                                                                                                                                                                                                                                     Answer with a number only: Which vitamin is supplied from only animal source: 1.Vitamin C 2.Vitamin B7 3.Vitamin B12 4.Vitamin D
# ...

# %%
medQuestion=[]
medType=[]
medResulta=[] #1 for correct and 0 for wrong
medResultc=[]
medResultd=[]
medResultg=[]

for i, row in med.iterrows():
#     medQuestion.append(row["Question"])
    medType.append(row["TYPE"])
    ada=str(row["ADA"])
    curie=str(row['CURIE'])
    davinci=str(row['DAVINCI'])
    gpt3= str(row['GPT 3.5'])
    corr=str((row['Correct']))
    if(corr==ada):
        medResulta.append('1')
    else:
        medResulta.append('0')
    if(corr==curie):
        medResultc.append('1')
    else:
        medResultc.append('0')
    if(corr==davinci):
        medResultd.append('1')
    else:
        medResultd.append('0')
    if(corr==gpt3):
        medResultg.append('1')
    else:
        medResultg.append('0')

# %%
list_of_tuples = list(zip(medType,medResulta,medResultc, medResultd, medResultg))
med1 = pd.DataFrame(list_of_tuples, columns=["TYPE", "ADA", "CURIE", "DAVINCI", "GPT 3.5"])
med1
# Out:
#     TYPE ADA CURIE DAVINCI GPT 3.5
# 0      F   0     0       0       1
# 1      F   0     0       1       0
# 2      L   1     0       1       0
# 3      F   0     0       0       1
# 4      F   0     0       0       1
# ..   ...  ..   ...     ...     ...
# 995    F   1     0       0       1
# 996    F   0     0       0       1
# 997    L   0     0       0       0
# 998    F   0     0       0       0
# 999    F   0     0       0       0
#
# [1000 rows x 5 columns]

# %%
big_df = pd.concat([math1, hist1, med1], ignore_index=True)
big_df
# Out:
#      TYPE ADA CURIE DAVINCI GPT 3.5
# 0       L   0     0       0       1
# 1       L   0     0       1       0
# 2       L   0     0       1       0
# 3       L   0     0       0       1
# 4       L   1     0       0       0
# ...   ...  ..   ...     ...     ...
# 2160    F   1     0       0       1
# 2161    F   0     0       0       1
# 2162    L   0     0       0       0
# 2163    F   0     0       0       0
# 2164    F   0     0       0       0
#
# [2165 rows x 5 columns]

# %%
big_df.to_csv('ALLSUB.csv')

# %%
big_df['TYPE'].value_counts()
# here we can see 1510 logical questions and 655 factual questions
# Out:
# L    1510
# F     655
# Name: TYPE, dtype: int64

# %%
big_df.groupby(['TYPE']).count()
# Out:
#        ADA  CURIE  DAVINCI  GPT 3.5
# TYPE
# F      655    655      655      655
# L     1510   1510     1510     1510

# %%
fact= big_df[big_df['TYPE']=='F']
fact.head()
# Out:
#      TYPE ADA CURIE DAVINCI GPT 3.5
# 1000    F   0     1       1       1
# 1001    F   0     0       1       1
# 1002    F   0     0       0       1
# 1003    F   0     0       1       0
# 1004    F   0     0       1       1

# %%
logic= big_df[big_df['TYPE']=='L']
logic.head()
# Out:
#   TYPE ADA CURIE DAVINCI GPT 3.5
# 0    L   0     0       0       1
# 1    L   0     0       1       0
# 2    L   0     0       1       0
# 3    L   0     0       0       1
# 4    L   1     0       0       0

# %%
print('FACTUAL: \nAda correct ')
print((fact['ADA']=='1').sum())
print('Curie correct ')
print((fact['CURIE']=='1').sum())
print('Davinci correct ')
print((fact['DAVINCI']=='1').sum())
print('GPT -3.5 correct ')
print((fact['GPT 3.5']=='1').sum())
print('----------------')
print('LOGICAL: \nAda correct ')
print((logic['ADA']=='1').sum())
print('Curie correct ')
print((logic['CURIE']=='1').sum())
print('Davinci correct ')
print((logic['DAVINCI']=='1').sum())
print('GPT -3.5 correct ')
print((logic['GPT 3.5']=='1').sum())
# Out:
# FACTUAL:
# Ada correct
# 100
# Curie correct
# 74
# Davinci correct
# 302
# GPT -3.5 correct
# 390
# ----------------
# LOGICAL:
# Ada correct
# 155
# Curie correct
# 138
# Davinci correct
# 461
# GPT -3.5 correct
# 530

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
df = pd.read_excel(open('GPTHist.xlsx','rb'))
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Question  \
# ...

# %%
hi=df[:20]
me=df[20:40]
ma=df[40:60]

# %%
#USing gpt 4
# Rate limit reached for 10KTPM-200RPM in organization org-Q2SzhomqX88CDE6FQtSA9Csr on tokens per min. Limit: 10000 / min. Please try again in 6ms.

import backoff  # for exponential backoff
import openai
openai.api_key = "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"

from tenacity import (
    retry,
    stop_after_attempt,
    wait_random_exponential,
)  # for exponential backoff


@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(6))
def completion_with_backoff(**kwargs):
    return openai.ChatCompletion.create(**kwargs)


for i in range(0, 10):
    ans= completion_with_backoff(
    model = "gpt-4", 
    temperature = 0.8, 
    max_tokens = 2000,
    messages = [{"role": "system", "content": hi.loc[i,"Question"]}]
    )    
    hi.loc[i, ['Answer']] = ans.choices[0].message.content
hi
# Out:
# C:\Users\SANJANA\AppData\Local\Temp\ipykernel_8328\4234455897.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hi.loc[i, ['Answer']] = ans.choices[0].message.content
# C:\Users\SANJANA\AppData\Local\Temp\ipykernel_8328\4234455897.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hi.loc[i, ['Answer']] = ans.choices[0].message.content
# C:\Users\SANJANA\AppData\Local\Temp\ipykernel_8328\4234455897.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range(58, 60):
    ans= completion_with_backoff(
    model = "gpt-4", 
    temperature = 0.8, 
    max_tokens = 2000,
    messages = [{"role": "system", "content": ma.loc[i,"Question"]}]
    )    
    ma.loc[i, ['Answer']] = ans.choices[0].message.content
# Out:
# C:\Users\SANJANA\AppData\Local\Temp\ipykernel_8328\3973973480.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ma.loc[i, ['Answer']] = ans.choices[0].message.content
# C:\Users\SANJANA\AppData\Local\Temp\ipykernel_8328\3973973480.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ma.loc[i, ['Answer']] = ans.choices[0].message.content

# %%
for i in range(37, 40):
    ans= completion_with_backoff(
    model = "gpt-4", 
    temperature = 0.8, 
    max_tokens = 2000,
    messages = [{"role": "system", "content": me.loc[i,"Question"]}]
    )    
    me.loc[i, ['Answer']] = ans.choices[0].message.content
me
# Out:
# C:\Users\SANJANA\AppData\Local\Temp\ipykernel_8328\779602718.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   me.loc[i, ['Answer']] = ans.choices[0].message.content
# C:\Users\SANJANA\AppData\Local\Temp\ipykernel_8328\779602718.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   me.loc[i, ['Answer']] = ans.choices[0].message.content
# C:\Users\SANJANA\AppData\Local\Temp\ipykernel_8328\779602718.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
hi
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Question  \
# ...

# %%
ma
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                   Question  \
# 40                                                                                                                                                                                                                   Answer only with the correct letter: there are 10 girls and 20 boys in a classroom . what is the ratio of girls to boys ? a ) 1 / 2 , b ) 1 / 3 , c ) 1 / 5 , d ) 10 / 30 , e ) 2 / 5
# ...
