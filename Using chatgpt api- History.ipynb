# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_excel(open('History Questions.xlsx','rb'))
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Question  \
# ...

# %%
len(df)
# Out:
# 165

# %%
import pandas as pd
table1Question=[]
table1Correct=[]
table1Answer=[]

for i, row in df.iloc[:1000].iterrows():
    table1Question.append("Answer with a letter only: " + row["Question"])
    table1Correct.append(row["Correct"])
    table1Answer.append("0")

# %%
list_of_tuples = list(zip(table1Question,table1Correct,table1Answer))
table1 = pd.DataFrame(list_of_tuples, columns=["Question", "Correct", "Answer"])
table1
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Question  \
# ...

# %% [markdown]
# # GPT-3.5 turbo

# %%
import openai  # for OpenAI API calls
openai.api_key = "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"
from tenacity import (
    retry,
    stop_after_attempt,
    wait_random_exponential,
)  # for exponential backoff


@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(6))
def completion_with_backoff(**kwargs):
    return openai.ChatCompletion.create(**kwargs)

# %%
for i in range(0, len(table1)):
    ans= completion_with_backoff(
    model = "gpt-3.5-turbo", 
    temperature = 0.8, 
    max_tokens = 2000,
    messages = [{"role": "system", "content": table1.loc[i,"Question"]}])    
    table1.loc[i, ['Answer']] = ans.choices[0].message.content

# %%
table1
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Question  \
# ...

# %%
for i in range(0, len(table1)):
    print(table1.loc[i, ['Answer']])
# Out:
# Answer    D
# Name: 0, dtype: object
# Answer    C
# Name: 1, dtype: object
# Answer    C. The Olmec civilization in Mesoamerica
# Name: 2, dtype: object
# Answer    B
# Name: 3, dtype: object
# Answer    D. Daoism
# Name: 4, dtype: object
# Answer    B. Greek and Roman
# Name: 5, dtype: object
# Answer    A
# Name: 6, dtype: object
# Answer    D
# Name: 7, dtype: object
# Answer    A. Power in the Han dynasty was concentrated in a centralized bureaucracy dominated by Confucian scholars while power in the Roman Republic was shared among the major landowning families of Rome.
# Name: 8, dtype: object
# Answer    B
# Name: 9, dtype: object
# Answer    C
# Name: 10, dtype: object
# Answer    C. Attacks by militarily superior horse- mounted steppe tribesmen equipped with strong bows; internal revolts due to increased taxes and weakening central authority; weak emperors and corrupt bureaucracy.
# Name: 11, dtype: object
# Answer    B. The Silk Road
# Name: 12, dtype: object
# Answer    D
# ...

# %%
#cleaning
for i in range(0, len(table1)):
    s=table1.loc[i, ['Answer']].astype("string")[0][:3]
    if ((s.find('A')!=-1) or (s.find('a')!=-1)):
        table1.loc[i, ['Answer']] = 'A'
    elif ((s.find('B')!=-1) or (s.find('b')!=-1)):
        table1.loc[i, ['Answer']] = 'B'
    elif ((s.find('C')!=-1) or (s.find('c')!=-1)):
        table1.loc[i, ['Answer']] = 'C'
    elif ((s.find('D')!=-1) or (s.find('d')!=-1)):
        table1.loc[i, ['Answer']] = 'D'
    elif ((s.find('E')!=-1) or (s.find('e')!=-1)):
        table1.loc[i, ['Answer']] = 'E'
    else: 
        table1.loc[i, ['Answer']] = 0
table1
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Question  \
# ...

# %%
j=0
for i in range(0, len(table1)):
    ans=(table1.loc[i, ['Answer']][0])
    corr=(table1.loc[i, ['Correct']]).astype("string")[0]
    if(ans==corr):
        j=j+1
print(j)
print((j/165)*100)
# Out:
# 124
# 75.15151515151514

# %%
#table1 has 1000 questions solved using gpt-3.5-turbo
#Correct contains the right option and answer contains the option given by the model
table1.to_csv('Hist165GPT3.csv')

# %% [markdown]
# # ada

# %%
import pandas as pd
table2 = pd.DataFrame(list_of_tuples, columns=["Question", "Correct", "Answer"])
table2
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Question  \
# ...

# %%
for i in range(0, len(table2)):
    ans= openai.Completion.create(model = "text-ada-001", prompt=table2.loc[i,"Question"])
    table2.loc[i, ['Answer']] = ans['choices'][0]['text']
table2
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Question  \
# ...

# %%
 for i in range(0, len(table2)):
    print(table2.loc[i, ['Answer']])
# Out:
# Answer     E. The Customs period\n\nA. The Paleolithic
# Name: 0, dtype: object
# Answer
# Name: 1, dtype: object
# Answer    \n\nA. The Mogul Empire in India\n\nB. The Tok
# Name: 2, dtype: object
# Answer     systems
# Name: 3, dtype: object
# Answer    \n\nAnswer:\n\n1. Historic sources mention the following about farmers in
# Name: 4, dtype: object
# Answer    \n\nSumerian and Egyptian
# Name: 5, dtype: object
# Answer     E. The New Roman Empire, characterized by the rule ofgovernor chanceller
# Name: 6, dtype: object
# Answer    \n\nC. Ottoman D. Persian\n\nE. Rome
# Name: 7, dtype: object
# Answer     E. Power in the Han dynasty was most powerful when it was tucked away in
# Name: 8, dtype: object
# Answer
# Name: 9, dtype: object
# Answer
# Name: 10, dtype: object
# Answer     E.Failure of the Yu Dynasty leadership in accepted rule, see Pancuria.
# Name: 11, dtype: object
# Answer     A.\n\nA. The Silk Road
# Name: 12, dtype: object
# Answer    \n\nVarna
# ...

# %%
#cleaning the data:
#Find if the numbers 1, 2 , 3 or 4 are present in the answer?
for i in range(0, len(table2)):
    s=table2.loc[i, ['Answer']].astype("string")[0]
    if ((s.find('A)')!=-1) or (s.find('a)')!=-1) or (s.find('A.')!=-1) or (s[:5].find('A')!=-1)):
        table2.loc[i, ['Answer']] = 'A'
    elif ((s.find('B)')!=-1) or (s.find('b)')!=-1) or (s.find('B.')!=-1) or (s[:5].find('B')!=-1)):
        table2.loc[i, ['Answer']] = 'B'
    elif ((s.find('C)')!=-1) or (s.find('c)')!=-1) or (s.find('C.')!=-1) or (s[:5].find('C')!=-1)):
        table2.loc[i, ['Answer']] = 'C'
    elif ((s.find('D)')!=-1) or (s.find('d)')!=-1) or (s.find('D.')!=-1) or (s[:5].find('D')!=-1)):
        table2.loc[i, ['Answer']] = 'D'
    elif ((s.find('E)')!=-1) or (s.find('e)')!=-1) or (s.find('E.')!=-1) or (s[:5].find('E')!=-1)):
        table2.loc[i, ['Answer']] = 'E'
    else: 
        table2.loc[i, ['Answer']] = 0

# %%
table2[:50]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Question  \
# ...

# %%
j=0
for i in range(0, len(table2)):
    ans=(table2.loc[i, ['Answer']][0])
    corr=(table2.loc[i, ['Correct']]).astype("string")[0]
    if(ans==corr):
        j=j+1
print(j)
print((j/165)*100)
# Out:
# 4
# 2.4242424242424243

# %%
table2.to_csv('Hist165ada.csv')

# %% [markdown]
# # Davinci

# %%
import pandas as pd

table3 = pd.DataFrame(list_of_tuples, columns=["Question", "Correct", "Answer"])
table3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Question  \
# ...

# %%
for i in range(0, len(table3)):
    ans= openai.Completion.create(model = "text-davinci-003", prompt=table3.loc[i,"Question"])
    table3.loc[i, ['Answer']] = ans['choices'][0]['text']
table3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Question  \
# ...

# %%
for i in range(0, len(table3)):
    print(table3.loc[i, ['Answer']])
# Out:
# Answer    \n\nD. The Neolithic
# Name: 0, dtype: object
# Answer    \n\nC.
# Name: 1, dtype: object
# Answer    \n\nA. The Mogul Empire in India
# Name: 2, dtype: object
# Answer    \n\nA. Monotheism
# Name: 3, dtype: object
# Answer    \n\nD. Daoism
# Name: 4, dtype: object
# Answer    \n\nC. Egyptian and Greek
# Name: 5, dtype: object
# Answer    \n\nA. Greek trading empires and the conquests of Alexander the Great spread
# Name: 6, dtype: object
# Answer    \n\nD. Persian
# Name: 7, dtype: object
# Answer    \n\nC. Power in the Han dynasty was concentrated in a centralized bureaucracy dominated
# Name: 8, dtype: object
# Answer    \n\nD
# Name: 9, dtype: object
# Answer    \n\nC.
# Name: 10, dtype: object
# Answer    \n\nC. Attacks by militarily superior horse-mounted steppe tribesmen
# Name: 11, dtype: object
# Answer    \n\nB. The Silk Road
# Name: 12, dtype: object
# Answer    \n\nD. Baghdad
# Name: 13, dtype: object
# Answer    \n\nC. The construction of the Grand Canal
# ...

# %%
#cleaning the data:
#Find if the numbers 1, 2 , 3 or 4 are present in the answer?
for i in range(0, len(table3)):
    s=table3.loc[i, ['Answer']].astype("string")[0]
    if ((s.find('A)')!=-1) or (s.find('a)')!=-1) or (s.find('A.')!=-1) or (s[:5].find('A')!=-1)):
        table3.loc[i, ['Answer']] = 'A'
    elif ((s.find('B)')!=-1) or (s.find('b)')!=-1) or (s.find('B.')!=-1) or (s[:5].find('B')!=-1)):
        table3.loc[i, ['Answer']] = 'B'
    elif ((s.find('C)')!=-1) or (s.find('c)')!=-1) or (s.find('C.')!=-1) or (s[:5].find('C')!=-1)):
        table3.loc[i, ['Answer']] = 'C'
    elif ((s.find('D)')!=-1) or (s.find('d)')!=-1) or (s.find('D.')!=-1) or (s[:5].find('D')!=-1)):
        table3.loc[i, ['Answer']] = 'D'
    elif ((s.find('E)')!=-1) or (s.find('e)')!=-1) or (s.find('E.')!=-1) or (s[:5].find('E')!=-1)):
        table3.loc[i, ['Answer']] = 'E'
    else: 
        table3.loc[i, ['Answer']] = 0

# %%
table3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Question  \
# ...

# %%
j=0
for i in range(0, len(table3)):
    ans=(table3.loc[i, ['Answer']][0])
    corr=(table3.loc[i, ['Correct']]).astype("string")[0]
    if(ans==corr):
        j=j+1
print(j)
print((j/165)*100)
# Out:
# 103
# 62.42424242424243

# %%
table3.to_csv('Hist165Davinci.csv')

# %% [markdown]
# # text-curie-001

# %%
table4 = pd.DataFrame(list_of_tuples, columns=["Question", "Correct", "Answer"])
table4
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Question  \
# ...

# %%
for i in range(0, len(table4)):
    ans= openai.Completion.create(model = "text-curie-001", prompt=table4.loc[i,"Question"])
    table4.loc[i, ['Answer']] = ans['choices'][0]['text']
table4
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Question  \
# ...

# %%
table4[:50]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Question  \
# ...

# %%
for i in range(0, len(table4)):
    print(table4.loc[i, ['Answer']])
# Out:
# Answer    D
# Name: 0, dtype: object
# Answer    \n\nA. In Northern Europe, nomadic hunters began to produce more complex
# Name: 1, dtype: object
# Answer    \n\nD. The Athenian city- state in ancient Greece
# Name: 2, dtype: object
# Answer     E. Prophets
# Name: 3, dtype: object
# Answer
# Name: 4, dtype: object
# Answer
# Name: 5, dtype: object
# Answer    \n\nThe presence of Greek architectural styles throughout the Middle East and the Mediterranean can
# Name: 6, dtype: object
# Answer
# Name: 7, dtype: object
# Answer
# Name: 8, dtype: object
# Answer    \n\nThe dynastic cycle is a pattern that describes how Chinese dynasties
# Name: 9, dtype: object
# Answer    \n\nA. The legions stopped using the traditional phalanx formation that was
# Name: 10, dtype: object
# Answer    \n\nC. Attacks by militarily superior horse-mounted steppe tribesmen
# Name: 11, dtype: object
# Answer    \n\n\nThe major trade network between Asia and Europe is the Silk Road.
# Name: 12, dtype: object
# ...

# %%
#cleaning the data:
#Find if the numbers 1, 2 , 3 or 4 are present in the answer?
for i in range(0, len(table4)):
    s=table4.loc[i, ['Answer']].astype("string")[0]
    if ((s.find('A)')!=-1) or (s.find('a)')!=-1) or (s.find('A.')!=-1) or (s[:5].find('A')!=-1)):
        table4.loc[i, ['Answer']] = 'A'
    elif ((s.find('B)')!=-1) or (s.find('b)')!=-1) or (s.find('B.')!=-1) or (s[:5].find('B')!=-1)):
        table4.loc[i, ['Answer']] = 'B'
    elif ((s.find('C)')!=-1) or (s.find('c)')!=-1) or (s.find('C.')!=-1) or (s[:5].find('C')!=-1)):
        table4.loc[i, ['Answer']] = 'C'
    elif ((s.find('D)')!=-1) or (s.find('d)')!=-1) or (s.find('D.')!=-1) or (s[:5].find('D')!=-1)):
        table4.loc[i, ['Answer']] = 'D'
    elif ((s.find('E)')!=-1) or (s.find('e)')!=-1) or (s.find('E.')!=-1) or (s[:5].find('E')!=-1)):
        table4.loc[i, ['Answer']] = 'E'
    else: 
        table4.loc[i, ['Answer']] = 0

# %%
j=0
for i in range(0, len(table4)):
    ans=(table4.loc[i, ['Answer']][0])
    corr=(table4.loc[i, ['Correct']]).astype("string")[0]
    if(ans==corr):
        j=j+1
print(j)
print((j/165)*100)
# Out:
# 29
# 17.575757575757574

# %%
table4.to_csv('Hist165Curie.csv')
