# %%
import openai

# %%
openai.api_key = "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"

# %%
import pandas as pd
df = pd.read_csv("USEMedTrain.csv")
df
#Df contains all 1279747 enteries.
# Out:
#         Unnamed: 0                                           Question  \
# 0                0  Which vitamin is supplied from only animal sou...
# 1                1  All of the following are surgical options for ...
# 2                2  Following endaerectomy on the right common car...
# 3                3   Growth hormone has its effect on growth through?
# 4                4     Scrub typhus is transmitted by: September 2004
# ...            ...                                                ...
# 182816      182816  Most common site for extra mammary Paget&;s di...
# 182817      182817       Inferior Rib notching is seen in all except?
# 182818      182818  Which is false regarding cryptococcus neoformans?
# 182819      182819  Histopathological finding of gluten hypersensi...
# 182820      182820  All except one are centrally acting muscle blo...
#
#                            Option1                              Option2  \
# ...

# %%
df.size
# Out:
# 1279747

# %% [markdown]
# # Table 1-  1000 questions

# %%
import pandas as pd

table1Question=[]
table1Correct=[]
table1Answer=[]

for i, row in df.iloc[:1000].iterrows():
    table1Question.append("Answer with a number only: " + row["Question"]+" 1."+ row["Option1"]+" 2."+ row["Option2"]+" 3."+ row["Option3"]+" 4."+ row["Option4"])
    table1Correct.append(row["Correct"])
    table1Answer.append("0")
#We have first 1000 enteries in table1

# %%
list_of_tuples = list(zip(table1Question,table1Correct,table1Answer))
table1 = pd.DataFrame(list_of_tuples, columns=["Question", "Correct", "Answer"])
table1
# Out:
#                                               Question  Correct Answer
# 0    Answer with a number only: Which vitamin is su...        3      0
# 1    Answer with a number only: All of the followin...        4      0
# 2    Answer with a number only: Following endaerect...        1      0
# 3    Answer with a number only: Growth hormone has ...        2      0
# 4    Answer with a number only: Scrub typhus is tra...        3      0
# ..                                                 ...      ...    ...
# 995  Answer with a number only: Millenium developme...        2      0
# 996  Answer with a number only: In the stage of Gre...        4      0
# 997  Answer with a number only: Twin pregnancy, but...        2      0
# 998  Answer with a number only: Low bih weight baby...        4      0
# 999  Answer with a number only: Drug of choice for ...        2      0
#
# [1000 rows x 3 columns]

# %% [markdown]
# # gpt-3.5-turbo

# %%
import openai  # for OpenAI API calls
from tenacity import (
    retry,
    stop_after_attempt,
    wait_random_exponential,
)  # for exponential backoff


@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(6))
def completion_with_backoff(**kwargs):
    return openai.ChatCompletion.create(**kwargs)

# %%
for i in range(0, len(table1)):
    ans= completion_with_backoff(
    model = "gpt-3.5-turbo", 
    temperature = 0.8, 
    max_tokens = 2000,
    messages = [{"role": "system", "content": table1.loc[i,"Question"]}]
    )    
    table1.loc[i, ['Answer']] = ans.choices[0].message.content

# %%
table1
# Out:
#                                                                                                                                                                                                                                                                                                                                                               Question  \
# 0                                                                                                                                                                                                                                     Answer with a number only: Which vitamin is supplied from only animal source: 1.Vitamin C 2.Vitamin B7 3.Vitamin B12 4.Vitamin D
# ...

# %%
for i in range(0, len(table1)):
    print(table1.loc[i, ['Answer']])
# Out:
# Answer    3
# Name: 0, dtype: object
# Answer    1
# Name: 1, dtype: object
# Answer    4. Nasociliary artery
# Name: 2, dtype: object
# Answer    2
# Name: 3, dtype: object
# Answer    3
# Name: 4, dtype: object
# Answer    4
# Name: 5, dtype: object
# Answer    3
# Name: 6, dtype: object
# Answer    2.bc
# Name: 7, dtype: object
# Answer    3. Deficit of expression by gesture
# Name: 8, dtype: object
# Answer    1
# Name: 9, dtype: object
# Answer    3. 2, 4, 5 True & 1, 3 false
# Name: 10, dtype: object
# Answer    3
# Name: 11, dtype: object
# Answer    4
# Name: 12, dtype: object
# Answer    3
# Name: 13, dtype: object
# Answer    3
# Name: 14, dtype: object
# Answer    1
# Name: 15, dtype: object
# Answer    3
# Name: 16, dtype: object
# Answer    2
# Name: 17, dtype: object
# Answer    2
# Name: 18, dtype: object
# Answer    3
# Name: 19, dtype: object
# Answer    2
# Name: 20, dtype: object
# Answer    1
# Name: 21, dtype: object
# Answer    3.0.9
# Name: 22, dtype: object
# ...

# %%
for i in range(0, len(table1)):
    table1.loc[i, ['Answer']] = table1.loc[i, ['Answer']][0][0]
table1
# Out:
#                                                                                                                                                                                                                                                                                                                                                               Question  \
# 0                                                                                                                                                                                                                                     Answer with a number only: Which vitamin is supplied from only animal source: 1.Vitamin C 2.Vitamin B7 3.Vitamin B12 4.Vitamin D
# ...

# %%
#table1 has 1000 questions solved using gpt-3.5-turbo
#Correct contains the right option and answer contains the option given by the model
table1.to_csv('Med1000GPT3.csv')

# %% [markdown]
# #  ada

# %%
import pandas as pd

table2Question=[]
table2Correct=[]
table2Answer=[]

for i, row in df.iloc[:1000].iterrows():
    table2Question.append("Answer with a number only: " + row["Question"]+" 1."+ row["Option1"]+" 2."+ row["Option2"]+" 3."+ row["Option3"]+" 4."+ row["Option4"])
    table2Correct.append(row["Correct"])
    table2Answer.append("0")
#We have first 1000 enteries in table2
list_of_tuples = list(zip(table2Question,table2Correct,table2Answer))
pd.set_option('display.max_colwidth', None)
table2 = pd.DataFrame(list_of_tuples, columns=["Question", "Correct", "Answer"])
table2
# Out:
#                                                                                                                                                                                                                                                                                                                                                               Question  \
# 0                                                                                                                                                                                                                                     Answer with a number only: Which vitamin is supplied from only animal source: 1.Vitamin C 2.Vitamin B7 3.Vitamin B12 4.Vitamin D
# ...

# %%
for i in range(0, len(table2)):
    ans= openai.Completion.create(model = "text-ada-001", prompt=table3.loc[i,"Question"])
    table2.loc[i, ['Answer']] = ans['choices'][0]['text']
table2
# Out:
#                                                                                                                                                                                                                                                                                                                                                               Question  \
# 0                                                                                                                                                                                                                                     Answer with a number only: Which vitamin is supplied from only animal source: 1.Vitamin C 2.Vitamin B7 3.Vitamin B12 4.Vitamin D
# ...

# %%
 for i in range(0, len(table2)):
    print(table2.loc[i, ['Answer']])
# Out:
# Answer    \n\n1.Vitamin C\n1.Vitamin B7\n1
# Name: 0, dtype: object
# Answer     means 5.Pulmonary hypertension\n All of the following are surgical options for
# Name: 1, dtype: object
# Answer     5.Ocular aery 6.vocal aery\n\n1.
# Name: 2, dtype: object
# Answer    \n\n1.Directly\n2.IG1-1\n3.
# Name: 3, dtype: object
# Answer    \n\n1. Louse 2. Tick 3. Mite 4. Milk
# Name: 4, dtype: object
# Answer    \n\n1.Punctation\n2.Mosaication\n3.
# Name: 5, dtype: object
# Answer    \n\n1. Neither is a good test for 1.Anal fiss
# Name: 6, dtype: object
# Answer     5.aac\n\nMetabolism:\n\nRemifenteuth
# Name: 7, dtype: object
# Answer    \n\n1.Hypomimia is ? 1.Decreased ability to
# Name: 8, dtype: object
# Answer    \n\n1.Clostridium tetani 2.Clostridium
# Name: 9, dtype: object
# Answer    \n\nFalse
# Name: 10, dtype: object
# Answer    \n\nThe pharmakokinetic change occurring in geriatric patient is due to
# Name: 11, dtype: object
# ...

# %%
#cleaning the data:
#Find if the numbers 1, 2 , 3 or 4 are present in the answer?
for i in range(0, len(table2)):
    s=table2.loc[i, ['Answer']].astype("string")[0]
    if (s.find('1')!=-1):
        table2.loc[i, ['Answer']] = 1
    elif (s.find('2')!=-1):
        table2.loc[i, ['Answer']] = 2
    elif (s.find('3')!=-1):
        table2.loc[i, ['Answer']] = 3
    elif (s.find('4')!=-1):
        table2.loc[i, ['Answer']] = 4
    else: 
        table2.loc[i, ['Answer']] = 0
table2
# Out:
#                                                                                                                                                                                                                                                                                                                                                               Question  \
# 0                                                                                                                                                                                                                                     Answer with a number only: Which vitamin is supplied from only animal source: 1.Vitamin C 2.Vitamin B7 3.Vitamin B12 4.Vitamin D
# ...

# %%
table2.to_csv('Med1000ada.csv')

# %% [markdown]
# Table 1 and 2: /v1/chat/completions endpoint
# Models that can be used are : gpt-4, gpt-4-0613, gpt-4-32k, gpt-4-32k-0613, gpt-3.5-turbo, gpt-3.5-turbo-0613, gpt-3.5-turbo-16k, gpt-3.5-turbo-16k-0613

# %% [markdown]
# For the remaining tables of GPT 3 we use /v1/completions;
# models are text-davinci-003, text-davinci-002, text-curie-001, text-babbage-001, text-ada-001

# %% [markdown]
# # Table 3:  text-davinci-003 Very capable, faster ,2,049 tokens

# %%
import pandas as pd

table3 = pd.DataFrame(list_of_tuples, columns=["Question", "Correct", "Answer"])
table3
# Out:
#                                                                                                                                                                                                                                                                                                                                                               Question  \
# 0                                                                                                                                                                                                                                     Answer with a number only: Which vitamin is supplied from only animal source: 1.Vitamin C 2.Vitamin B7 3.Vitamin B12 4.Vitamin D
# ...

# %%
for i in range(0, len(table3)):
    ans= openai.Completion.create(model = "text-davinci-003", prompt=table3.loc[i,"Question"])
    table3.loc[i, ['Answer']] = ans['choices'][0]['text']
table3
# Out:
#                                                                                                                                                                                                                                                                                                                                                               Question  \
# 0                                                                                                                                                                                                                                     Answer with a number only: Which vitamin is supplied from only animal source: 1.Vitamin C 2.Vitamin B7 3.Vitamin B12 4.Vitamin D
# ...

# %%
for i in range(0, len(table3)):
    print(table3.loc[i, ['Answer']])
# Out:
# Answer    \n\n3. Vitamin B12
# Name: 0, dtype: object
# Answer    \n\n4. Roux en Y Duodenal By pass
# Name: 1, dtype: object
# Answer    \n\n1.Central aery of the retina
# Name: 2, dtype: object
# Answer    \n\n1
# Name: 3, dtype: object
# Answer    \n\n2
# Name: 4, dtype: object
# Answer    \n\n1
# Name: 5, dtype: object
# Answer    \n\n1.No 2.No 3.No 4.No
# Name: 6, dtype: object
# Answer     5.abcd
# Name: 7, dtype: object
# Answer     5.Affective flattening\n\n5.Affective flattening
# Name: 8, dtype: object
# Answer    \n\n2
# Name: 9, dtype: object
# Answer
# Name: 10, dtype: object
# Answer     \n\n3.Renal clearance
# Name: 11, dtype: object
# Answer    \n\n2
# Name: 12, dtype: object
# Answer    \n\n4. Urine microscopy for malignant cytology cells
# Name: 13, dtype: object
# Answer    \n\n3.Adenosine receptors
# Name: 14, dtype: object
# Answer    \n\n2
# Name: 15, dtype: object
# Answer    \n\n1
# Name: 16, dtype: object
# Answer    \n\n2.Setting
# Name: 17, dtype: object
# ...

# %%
#cleaning the data:
#Find if the numbers 1, 2 , 3 or 4 are present in the answer?
for i in range(0, len(table3)):
    s=table3.loc[i, ['Answer']].astype("string")[0]
    if (s.find('1')!=-1):
        table3.loc[i, ['Answer']] = 1
    elif (s.find('2')!=-1):
        table3.loc[i, ['Answer']] = 2
    elif (s.find('3')!=-1):
        table3.loc[i, ['Answer']] = 3
    elif (s.find('4')!=-1):
        table3.loc[i, ['Answer']] = 4
    else: 
        table3.loc[i, ['Answer']] = 0
table3
# Out:
#                                                                                                                                                                                                                                                                                                                                                               Question  \
# 0                                                                                                                                                                                                                                     Answer with a number only: Which vitamin is supplied from only animal source: 1.Vitamin C 2.Vitamin B7 3.Vitamin B12 4.Vitamin D
# ...

# %%
table3.to_csv('Med1000davinci.csv')

# %% [markdown]
# # Table 4: text-curie-001

# %%
table4 = pd.DataFrame(list_of_tuples, columns=["Question", "Correct", "Answer"])
table4
# Out:
#                                                                                                                                                                                                                                                                                                                                                               Question  \
# 0                                                                                                                                                                                                                                     Answer with a number only: Which vitamin is supplied from only animal source: 1.Vitamin C 2.Vitamin B7 3.Vitamin B12 4.Vitamin D
# ...

# %%
for i in range(0, len(table4)):
    ans= openai.Completion.create(model = "text-curie-001", prompt=table4.loc[i,"Question"])
    table4.loc[i, ['Answer']] = ans['choices'][0]['text']
table4
# Out:
#                                                                                                                                                                                                                                                                                                                                                               Question  \
# 0                                                                                                                                                                                                                                     Answer with a number only: Which vitamin is supplied from only animal source: 1.Vitamin C 2.Vitamin B7 3.Vitamin B12 4.Vitamin D
# ...

# %%
for i in range(0, len(table4)):
    s=table4.loc[i, ['Answer']].astype("string")[0]
    if (s.find('1')!=-1):
        table4.loc[i, ['Answer']] = 1
    elif (s.find('2')!=-1):
        table4.loc[i, ['Answer']] = 2
    elif (s.find('3')!=-1):
        table4.loc[i, ['Answer']] = 3
    elif (s.find('4')!=-1):
        table4.loc[i, ['Answer']] = 4
    else: 
        table4.loc[i, ['Answer']] = 0
table4
# Out:
#                                                                                                                                                                                                                                                                                                                                                               Question  \
# 0                                                                                                                                                                                                                                     Answer with a number only: Which vitamin is supplied from only animal source: 1.Vitamin C 2.Vitamin B7 3.Vitamin B12 4.Vitamin D
# ...

# %%
table4.to_csv('Med1000Curie.csv')

# %% [markdown]
# # Results

# %%
j=0
for i in range(0, len(table1)):
    ans=(table1.loc[i, ['Answer']][0])
    corr=(table1.loc[i, ['Correct']]).astype("string")[0]
    if(ans==corr):
        j=j+1
print(j)
print((j/1000)*100)
#3.5
# Out:
# 542
# 54.2

# %%
j=0
for i in range(0, len(table2)):
    
    ans=(table2.loc[i, ['Answer']]).astype("string")[0]
    corr=(table2.loc[i, ['Correct']]).astype("string")[0]
    if(ans==corr):
        j=j+1
print(j)
print((j/1000)*100)
#ada
# Out:
# 198
# 19.8

# %%
j=0
for i in range(0, len(table3)):
    ans=(table3.loc[i, ['Answer']]).astype("string")[0]
    corr=(table3.loc[i, ['Correct']]).astype("string")[0]
    if(ans==corr):
        j=j+1
print(j)
print((j/1000)*100)
#davinci
# Out:
# 411
# 41.099999999999994

# %%
j=0
for i in range(0, len(table4)):
    ans=(table4.loc[i, ['Answer']]).astype("string")[0]
    corr=(table4.loc[i, ['Correct']]).astype("string")[0]
    if(ans==corr):
        j=j+1
print(j)
print((j/1000)*100)
#Curie
# Out:
# 85
# 8.5

# %%
85/1000
# Out:
# 0.085

# %% [markdown]
# # Results
# Table 1 (gpt3.5-turbo): 286/500 =54.2%
# Table 2 ( ) :
# Table 3 (text-davinci-003): 185/500 =41.1%
# Table 4 (text-curie-001): 59/500 =8.5%

# %%
table5 = pd.DataFrame(list_of_tuples, columns=["Question", "Correct", "Answer"])
table5
# Out:
#                                               Question  Correct Answer
# 0    Answer with a number only: Which vitamin is su...        3      0
# 1    Answer with a number only: All of the followin...        4      0
# 2    Answer with a number only: Following endaerect...        1      0
# 3    Answer with a number only: Growth hormone has ...        2      0
# 4    Answer with a number only: Scrub typhus is tra...        3      0
# ..                                                 ...      ...    ...
# 995  Answer with a number only: Millenium developme...        2      0
# 996  Answer with a number only: In the stage of Gre...        4      0
# 997  Answer with a number only: Twin pregnancy, but...        2      0
# 998  Answer with a number only: Low bih weight baby...        4      0
# 999  Answer with a number only: Drug of choice for ...        2      0
#
# [1000 rows x 3 columns]

# %%
#TRY GPT 4
import backoff  # for exponential backoff

@backoff.on_exception(backoff.expo, openai.error.RateLimitError)
def completions_with_backoff(**kwargs):
    return openai.Completion.create(**kwargs)

for i in range(0, len(table5)):
    ans= completion_with_backoff(
    model = "gpt-4", 
    temperature = 0.8, 
    max_tokens = 2000,
    messages = [{"role": "system", "content": table5.loc[i,"Question"]}]
    )    
    table5.loc[i, ['Answer']] = ans.choices[0].message.content
table5
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\tenacity\__init__.py:407, in Retrying.__call__(self, fn, *args, **kwargs)
#     406 try:
# --> 407     result = fn(*args, **kwargs)
#     408 except BaseException:  # noqa: B902
#
# Input In [11], in completion_with_backoff(**kwargs)
#       9 @retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(6))
#      10 def completion_with_backoff(**kwargs):
# ---> 11     return openai.ChatCompletion.create(**kwargs)
#
# File ~\anaconda3\lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      24 try:
# ---> 25     return super().create(*args, **kwargs)
#      26 except TryAgain as e:
#
# ...

# %%
table5[:60]
# Out:
#                                              Question  Correct Answer
# 0   Answer with a number only: Which vitamin is su...        3      3
# 1   Answer with a number only: All of the followin...        4      4
# 2   Answer with a number only: Following endaerect...        1      1
# 3   Answer with a number only: Growth hormone has ...        2      2
# 4   Answer with a number only: Scrub typhus is tra...        3      3
# 5   Answer with a number only: Abnormal vascular p...        3      3
# 6   Answer with a number only: Per rectum examinat...        3      3
# 7   Answer with a number only: Characteristics of ...        3      4
# 8   Answer with a number only: Hypomimia is ? 1.De...        3      3
# 9   Answer with a number only: Naglers reaction is...        3      3
# 10  Answer with a number only: Which of the follow...        3      3
# 11  Answer with a number only: The pharmakokinetic...        3      3
# ...

# %%
for i in range(0, len(table2)):
    print(table5.loc[i, ['Answer']])

# %%
#Saving only first digit of the answer
for i in range(0, len(table2)):
    table5.loc[i, ['Answer']] = table5.loc[i, ['Answer']][0][0]
table5

# %%
table5.to_csv('table2.csv')

# %%
#SAMPLE:
#TRY GPT 4
import backoff  # for exponential backoff

@backoff.on_exception(backoff.expo, openai.error.RateLimitError)
def completions_with_backoff(**kwargs):
    return openai.Completion.create(**kwargs)

ans= completion_with_backoff(
    model = "gpt-3.5-turbo", 
    temperature = 0.8, 
    max_tokens = 2000,
    messages = [{"role": "system", "content": "Answer with a letter only: For what period would archaeologists first begin to find permanent human settlements? A. The Paleolithic B. The Classical Era C. The Bronze Age D. The Neolithic"}]
    )   
ans
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7owt6f7RQgpCjW3WGZojPfwEyxrzy at 0x26ea9973630> JSON: {
#   "id": "chatcmpl-7owt6f7RQgpCjW3WGZojPfwEyxrzy",
#   "object": "chat.completion",
#   "created": 1692377120,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "D. The Neolithic"
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 47,
#     "completion_tokens": 5,
#     "total_tokens": 52
#   }
# }

# %%
type(ans)
# Out:
# openai.openai_object.OpenAIObject

# %%
ans
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7owt6f7RQgpCjW3WGZojPfwEyxrzy at 0x26ea9973630> JSON: {
#   "id": "chatcmpl-7owt6f7RQgpCjW3WGZojPfwEyxrzy",
#   "object": "chat.completion",
#   "created": 1692377120,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "D. The Neolithic"
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 47,
#     "completion_tokens": 5,
#     "total_tokens": 52
#   }
# }

# %%
ans.choices[0].message.content
# Out:
# 'D. The Neolithic'
